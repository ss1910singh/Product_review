# %%
import requests
from bs4 import BeautifulSoup

# %%
HEADERS = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/116.0.5845.188 Safari/537.36',
    'Accept-Language': 'en-US,en;q=0.5'
}

URL =input("Enter url")

# %%
response = requests.get(URL, headers=HEADERS)
if response.status_code == 200:
    soup = BeautifulSoup(response.text, 'html.parser')

    product_title = soup.find('span', id='productTitle')
    if product_title:
        print("Product Title:", product_title.get_text(strip=True))

    feature_bullets = soup.find('div', id='feature-bullets')
    if feature_bullets:
        bullet_points = feature_bullets.find_all('li')
        bullet_points_text = [li.get_text(strip=True) for li in bullet_points]
        print("\nFeature Bullets:")
        for bullet in bullet_points_text:
            print("-", bullet)

    histogram_table = soup.find('ul', id='histogramTable')
    if histogram_table:
        print("\nRating Histogram Data:")
        rating_items = histogram_table.find_all('li')
        for item in rating_items:
            print("-", item.get_text(strip=True))

    card_padding = soup.find('div', class_='card-padding')
    if card_padding:
        a_row = card_padding.find('div', class_='a-row')
        if a_row:
            print("\nData from Card Padding (A-Row):")
            print(a_row.get_text(strip=True))

    review_list = soup.find_all('div', {'data-hook': 'review'})
    if review_list:
        print("\nCustomer Reviews:")
        for review in review_list:
            # Extracting reviewer name
            reviewer_name = review.find('span', class_='a-profile-name')
            reviewer_name_text = reviewer_name.get_text(strip=True) if reviewer_name else "Unknown Reviewer"

            # Extracting rating
            rating = review.find('i', {'data-hook': 'review-star-rating'})
            rating_text = rating.get_text(strip=True) if rating else "No rating"

            # Extracting review title
            review_title = review.find('a', {'data-hook': 'review-title'})
            review_title_text = review_title.get_text(strip=True) if review_title else "No title"

            # Extracting review date
            review_date = review.find('span', {'data-hook': 'review-date'})
            review_date_text = review_date.get_text(strip=True) if review_date else "No date"

            # Extracting review body
            review_body = review.find('span', {'data-hook': 'review-body'})
            review_body_text = review_body.get_text(strip=True) if review_body else "No body"

            # Printing review details
            print(f"Reviewer Name: {reviewer_name_text}")
            print(f"Rating: {rating_text}")
            print(f"Review Title: {review_title_text}")
            print(f"Date: {review_date_text}")
            print(f"Review Body: {review_body_text}\n")

    else:
        print("No customer reviews found.")
else:
    print("Failed to retrieve the webpage. Status code:", response.status_code)
# Out:
# Product Title: Durex Real Feel Condoms for Men - 10 Count | Latex Free
#
# Feature Bullets:
# - LATEX FREE CONDOMS: Durex Real Feel condoms are made from a non-latex material so that they are suitable for people who have an allergy to natural rubber latex proteins
# - DISCREET DELIVERY – Box delivered in discreet packaging with no branding or indication of parcel contents.
# - SIZE - All condoms (real feel) have a width of 56mm
# - DUREX QUALITY ?? With over 90 years of experience manufacturing condoms, Durex is the world??s No.1 brand.
# - All our condoms use only fine quality raw materials and every single one is electronically tested for holes and imperfections
#
# Rating Histogram Data:
# - 5 star4 star3 star2 star1 star5 star60%17%10%4%10%60%
# - 5 star4 star3 star2 star1 star4 star60%17%10%4%10%17%
# - 5 star4 star3 star2 star1 star3 star60%17%10%4%10%10%
# - 5 star4 star3 star2 star1 star2 star60%17%10%4%10%4%
# - 5 star4 star3 star2 star1 star1 star60%17%10%4%10%10%
#
# Data from Card Padding (A-Row):
# There was a problem filtering reviews right now. Please try again later.Mohammadjabir5.0 out of 5 starsBest condomReviewed in India on 6 October 2024Size: 1 count (Pack of 10)Pattern Name: CondomsVerified PurchaseFast desecrate delievry by amazon and best condom its feel like nothing wear very thin material latex free over all best quality and its good for long sexual durationRead moreHelpfulReportI cancel this because . there was no amazons packing.  & product also viewable. No proper packing. Package was open.5.0 out of 5 starsNiceReviewed in India on 24 September 2024Size: 1 count (Pack of 10)Pattern Name: CondomsVerified PurchaseI like this product.  Thanks for. Making my privacy.Read moreHelpfulReportAshish kumar4.0 out of 5 starsIts goodReviewed in India on 14 October 2024Size: 1 count (Pack of 10)Pattern Name: CondomsVerified PurchaseGood productRead moreHelpfulReportAmazon Customer5.0 out of 5 starsVery convenient to useReviewed in India on 5 October 2024Size: 1 count (Pack of 10)Pattern Name: CondomsVerified PurchaseValue for money and useful and highly recommended.Read moreHelpfulReportAKASH SINHA1.0 out of 5 starsNot so goodReviewed in India on 29 July 2024Size: 1 count (Pack of 10)Pattern Name: CondomsVerified PurchaseNot so good as was hyped by amazon. I would like to go for other alternatives tjan this productRead moreOne person found this helpfulHelpfulReportPlaceholder3.0 out of 5 starsSame as invisibleReviewed in India on 9 October 2024Size: 1 count (Pack of 3)Pattern Name: Real Feel CondomsVerified PurchaseSame as invisibleRead moreHelpfulReportAmazon Customer5.0 out of 5 starsYes it feels realReviewed in India on 3 September 2024Size: 1 count (Pack of 10)Pattern Name: CondomsVerified PurchaseI always prefer going without condom and all the ones I use was not giving a real feel, I always felt less pleasure.So I tried this and it is 90% close to real.Read more3 people found this helpfulHelpfulReportPUNIT TANNA5.0 out of 5 starsGood Qulity for useReviewed in India on 7 August 2024Size: 1 count (Pack of 10)Pattern Name: CondomsVerified PurchaseGoodRead more2 people found this helpfulHelpfulReport
#
# Customer Reviews:
# Reviewer Name: Mohammadjabir
# Rating: 5.0 out of 5 stars
# Review Title: 5.0 out of 5 starsBest condom
# Date: Reviewed in India on 6 October 2024
# Review Body: Fast desecrate delievry by amazon and best condom its feel like nothing wear very thin material latex free over all best quality and its good for long sexual durationRead more
#
# Reviewer Name: I cancel this because . there was no amazons packing.  & product also viewable. No proper packing. Package was open.
# Rating: 5.0 out of 5 stars
# Review Title: 5.0 out of 5 starsNice
# Date: Reviewed in India on 24 September 2024
# Review Body: I like this product.  Thanks for. Making my privacy.Read more
#
# Reviewer Name: Ashish kumar
# Rating: 4.0 out of 5 stars
# Review Title: 4.0 out of 5 starsIts good
# Date: Reviewed in India on 14 October 2024
# Review Body: Good productRead more
#
# Reviewer Name: Amazon Customer
# Rating: 5.0 out of 5 stars
# Review Title: 5.0 out of 5 starsVery convenient to use
# Date: Reviewed in India on 5 October 2024
# Review Body: Value for money and useful and highly recommended.Read more
#
# Reviewer Name: AKASH SINHA
# Rating: 1.0 out of 5 stars
# Review Title: 1.0 out of 5 starsNot so good
# Date: Reviewed in India on 29 July 2024
# Review Body: Not so good as was hyped by amazon. I would like to go for other alternatives tjan this productRead more
#
# Reviewer Name: Placeholder
# Rating: 3.0 out of 5 stars
# Review Title: 3.0 out of 5 starsSame as invisible
# Date: Reviewed in India on 9 October 2024
# Review Body: Same as invisibleRead more
#
# Reviewer Name: Amazon Customer
# Rating: 5.0 out of 5 stars
# Review Title: 5.0 out of 5 starsYes it feels real
# Date: Reviewed in India on 3 September 2024
# Review Body: I always prefer going without condom and all the ones I use was not giving a real feel, I always felt less pleasure.So I tried this and it is 90% close to real.Read more
#
# Reviewer Name: PUNIT TANNA
# Rating: 5.0 out of 5 stars
# Review Title: 5.0 out of 5 starsGood Qulity for use
# Date: Reviewed in India on 7 August 2024
# Review Body: GoodRead more
#
# Reviewer Name: Bella Lyn
# Rating: No rating
# Review Title: No title
# Date: Reviewed in the United States on 15 May 2021
# Review Body: good comfortable and doesnt irritateRead more
#
# Reviewer Name: Dan
# Rating: No rating
# Review Title: No title
# Date: Reviewed in the United Kingdom on 20 April 2017
# Review Body: Try these and be overwhelmed with an enormous sense of wellbeing. Amazing.Read more
#
# Reviewer Name: Mandie
# Rating: No rating
# Review Title: No title
# Date: Reviewed in the United States on 4 September 2016
# Review Body: These are absolutely amazing!! I tend to worry that non latex condoms can break more easily than latex but these don't and are very durable and they feel amazing!! I would definitely recommend these to anyone!!Read more
#
# Reviewer Name: George61
# Rating: No rating
# Review Title: No title
# Date: Reviewed in the United Kingdom on 10 September 2016
# Review Body: Very good.  Non latex.Read more
#
# Reviewer Name: Luis
# Rating: No rating
# Review Title: No title
# Date: Reviewed in the United States on 23 August 2024
# Review Body: BuenosRead more
