# %%
import requests
from bs4 import BeautifulSoup

# %%
HEADERS = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/116.0.5845.188 Safari/537.36',
    'Accept-Language': 'en-US,en;q=0.5'
}

URL =input("Enter url")

# %%
response = requests.get(URL, headers=HEADERS)
if response.status_code == 200:
    soup = BeautifulSoup(response.text, 'html.parser')

    product_title = soup.find('span', id='productTitle')
    if product_title:
        print("Product Title:", product_title.get_text(strip=True))

    feature_bullets = soup.find('div', id='feature-bullets')
    if feature_bullets:
        bullet_points = feature_bullets.find_all('li')
        bullet_points_text = [li.get_text(strip=True) for li in bullet_points]
        print("\nFeature Bullets:")
        for bullet in bullet_points_text:
            print("-", bullet)

    histogram_table = soup.find('ul', id='histogramTable')
    if histogram_table:
        print("\nRating Histogram Data:")
        rating_items = histogram_table.find_all('li')
        for item in rating_items:
            print("-", item.get_text(strip=True))

    card_padding = soup.find('div', class_='card-padding')
    if card_padding:
        a_row = card_padding.find('div', class_='a-row')
        if a_row:
            print("\nData from Card Padding (A-Row):")
            print(a_row.get_text(strip=True))

    review_list = soup.find_all('div', {'data-hook': 'review'})
    if review_list:
        print("\nCustomer Reviews:")
        for review in review_list:
            # Extracting reviewer name
            reviewer_name = review.find('span', class_='a-profile-name')
            reviewer_name_text = reviewer_name.get_text(strip=True) if reviewer_name else "Unknown Reviewer"

            # Extracting rating
            rating = review.find('i', {'data-hook': 'review-star-rating'})
            rating_text = rating.get_text(strip=True) if rating else "No rating"

            # Extracting review title
            review_title = review.find('a', {'data-hook': 'review-title'})
            review_title_text = review_title.get_text(strip=True) if review_title else "No title"

            # Extracting review date
            review_date = review.find('span', {'data-hook': 'review-date'})
            review_date_text = review_date.get_text(strip=True) if review_date else "No date"

            # Extracting review body
            review_body = review.find('span', {'data-hook': 'review-body'})
            review_body_text = review_body.get_text(strip=True) if review_body else "No body"

            # Printing review details
            print(f"Reviewer Name: {reviewer_name_text}")
            print(f"Rating: {rating_text}")
            print(f"Review Title: {review_title_text}")
            print(f"Date: {review_date_text}")
            print(f"Review Body: {review_body_text}\n")

    else:
        print("No customer reviews found.")
else:
    print("Failed to retrieve the webpage. Status code:", response.status_code)
# Out:
# Product Title: Lenovo LOQ 2024 13th Gen Intel Core i7-13650HX 15.6" (39.6cm) 144Hz 300Nits FHD Gaming Laptop (24GB/512GB SSD/Win 11/NVIDIA RTX 4060 8GB/MSO 21/1Yr ADP Free/3mon Game Pass/Grey/2.4Kg), 83DV00LXIN
#
# Feature Bullets:
# - Processor: Intel Core i7-13650HX | Speed: 2.6GHz (Base) - T, P-core up to 4.9GHz, E-core up to 3.6GHz | Cache:- 24MB
# - Display: 15.6" FHD (1920x1080) IPS Technology | 144 Hz Refresh Rate |Brightness: 300Nits Anti-glare | 100% sRGB | NVDIA G-Sync || Connectivity : Wifi 6E 11ax (2x2) | Bluetooth 5.2
# - Memory: 24GB RAM DDR5-4800 | Storage: 512GB SSD (Expandable upto 1TB)
# - Graphics: NVIDIA GeForce RTX 4060 8GB GDDR6 Dedicated Graphics, Boost clock 2370Mhz with max TGP 115W | G-Sync || Cooling: Dual 85mm 12V high-speed fans and larger vents ensure quiet and powerful cooling.
# - AI Engine : The Lenovo AI Engine+ and Lenovo LA1 AI Chip work together with the MUX Switch with NVIDIA Advanced Optimus for a truly epic boost in performance, at levels you've never seen before.
# - OS and Pre-Installed Softare: Pre-Loaded Windows 11 Home with Lifetime Validity | MS Office Home and Student 2021 || Battery Life: 60Wh (upto 6 Hrs) | Rapid Charge Pro (100pct. Battery Life in 80min )
# - Audio: 2x 2W HD Stereo Speakers | Nahimic Audio with Surround Sound, Sound Tracker, Night Mode, Sound Sharing & Content Profiles || Camera: FHD 1080p | E-cam Shutter | Integrated Dual Array Microphone
# - Keyboard: 1.5 mm Key Travel | 4-Zone RGB Keyboard with 100pct. Anti-Ghosting
# - Warranty: This genuine Lenovo laptop comes with 1 year onsite manufacturer warranty
# - Ports: 1x USB 2.0 | 2x USB 3.2 Gen 2 | 1x USB-C 3.2 Gen 2 (support data transfer, Power Delivery 140W and DisplayPort 1.4) | 1x HDMI 2.1, up to 8K/60Hz | 1x Headphone / microphone combo jack (3.5mm) | 1x Ethernet (RJ-45) | 1x Power connector
#
# Rating Histogram Data:
# - 5 star4 star3 star2 star1 star5 star37%15%18%0%30%37%
# - 5 star4 star3 star2 star1 star4 star37%15%18%0%30%15%
# - 5 star4 star3 star2 star1 star3 star37%15%18%0%30%18%
# - 5 star4 star3 star2 star1 star2 star37%15%18%0%30%0%
# - 5 star4 star3 star2 star1 star1 star37%15%18%0%30%30%
#
# Data from Card Padding (A-Row):
# There was a problem filtering reviews right now. Please try again later.SrinathNaidu.A5.0 out of 5 starsGood productReviewed in India on 8 October 2024Verified PurchaseI bought it on 4th Oct and recived next day So far it's very good and smooth to use as it have high processor we need to charge frequently and speakers are not great.Read moreSrinathNaidu.A5.0 out of 5 starsGood productReviewed in India on 8 October 2024I bought it on 4th Oct and recived next day So far it's very good and smooth to use as it have high processor we need to charge frequently and speakers are not great.Images in this review2 people found this helpfulHelpfulReportdarel philip1.0 out of 5 starslaptop stopped working after two daysReviewed in India on 18 July 2024Verified Purchasei bought this laptop on 8th july and it has been nothing but trouble it stopped working in 2 days the computer just wont start and intiated refund but has been waiting for 10 days now and no one has come to pick it up they keep on extending the pickup date and delaying while i dont have a laptop that i can use. dont buy from amazon thats all i can tell you. customer service at it’s worstRead more35 people found this helpfulHelpfulReportAmazon Customer3.0 out of 5 starsAverage quality LaptopReviewed in India on 28 July 2024Verified PurchaseThings I like:1 . Good specs2. Overall build qualityThings I don’t like:1. Very low volume.2. Screen reflects a lot of light . Hard to see in a bright room.3. Track pad is very unimpressive and low quality4. Needs charging frequently even while reading documentsRead more10 people found this helpfulHelpfulReportRohit1.0 out of 5 starsLasted just a month!Reviewed in India on 1 August 2024Verified PurchasePlease avoid Lenovo LOQ series with intel. The laptop architecture doesn’t support the high power CPU and GPU on board. My laptop motherboard fried in just a month while my son was playing a regular game! Lenovo replaced the motherboard after few weeks- again keeping fingers crossed that the motherboard doesn’t get fried again!Read more12 people found this helpfulHelpfulReportKundan Kumar1.0 out of 5 starsLaptop stopped working after 3 weeksReviewed in India on 21 July 2024Verified PurchaseLaptop stopped working after 3 weeks won't start. Trying to contact customer support.Absolute worst purchase of my life.I won't recommend buying.Still I haven't received my refund.Read more7 people found this helpfulHelpfulReportjasvinder3.0 out of 5 starsGodd laptopReviewed in India on 8 August 2024Verified PurchasePehle use karlu fir bataungaRead more8 people found this helpfulHelpfulReportAniket3.0 out of 5 starsLaptop is very much good.Reviewed in India on 3 July 2024Verified PurchaseI like the product very much ... But the negative point is battery.. company says its battery Lasts at least 5 to 6 hours . But the battery won't lasts even for 2 hours.Read more4 people found this helpfulHelpfulReport
#
# Customer Reviews:
# Reviewer Name: SrinathNaidu.A
# Rating: 5.0 out of 5 stars
# Review Title: 5.0 out of 5 starsGood product
# Date: Reviewed in India on 8 October 2024
# Review Body: I bought it on 4th Oct and recived next day So far it's very good and smooth to use as it have high processor we need to charge frequently and speakers are not great.Read more
#
# Reviewer Name: darel philip
# Rating: 1.0 out of 5 stars
# Review Title: 1.0 out of 5 starslaptop stopped working after two days
# Date: Reviewed in India on 18 July 2024
# Review Body: i bought this laptop on 8th july and it has been nothing but trouble it stopped working in 2 days the computer just wont start and intiated refund but has been waiting for 10 days now and no one has come to pick it up they keep on extending the pickup date and delaying while i dont have a laptop that i can use. dont buy from amazon thats all i can tell you. customer service at it’s worstRead more
#
# Reviewer Name: Amazon Customer
# Rating: 3.0 out of 5 stars
# Review Title: 3.0 out of 5 starsAverage quality Laptop
# Date: Reviewed in India on 28 July 2024
# Review Body: Things I like:1 . Good specs2. Overall build qualityThings I don’t like:1. Very low volume.2. Screen reflects a lot of light . Hard to see in a bright room.3. Track pad is very unimpressive and low quality4. Needs charging frequently even while reading documentsRead more
#
# Reviewer Name: Rohit
# Rating: 1.0 out of 5 stars
# Review Title: 1.0 out of 5 starsLasted just a month!
# Date: Reviewed in India on 1 August 2024
# Review Body: Please avoid Lenovo LOQ series with intel. The laptop architecture doesn’t support the high power CPU and GPU on board. My laptop motherboard fried in just a month while my son was playing a regular game! Lenovo replaced the motherboard after few weeks- again keeping fingers crossed that the motherboard doesn’t get fried again!Read more
#
# Reviewer Name: Kundan Kumar
# Rating: 1.0 out of 5 stars
# Review Title: 1.0 out of 5 starsLaptop stopped working after 3 weeks
# Date: Reviewed in India on 21 July 2024
# Review Body: Laptop stopped working after 3 weeks won't start. Trying to contact customer support.Absolute worst purchase of my life.I won't recommend buying.Still I haven't received my refund.Read more
#
# Reviewer Name: jasvinder
# Rating: 3.0 out of 5 stars
# Review Title: 3.0 out of 5 starsGodd laptop
# Date: Reviewed in India on 8 August 2024
# Review Body: Pehle use karlu fir bataungaRead more
#
# Reviewer Name: Aniket
# Rating: 3.0 out of 5 stars
# Review Title: 3.0 out of 5 starsLaptop is very much good.
# Date: Reviewed in India on 3 July 2024
# Review Body: I like the product very much ... But the negative point is battery.. company says its battery Lasts at least 5 to 6 hours . But the battery won't lasts even for 2 hours.Read more
